# %%
class Animales:
    especie = "ave"

    def __init__(self,nombre, color): 
        self.nombre = nombre 
        self.color = color

loro =

# %%
class superheroe:
    tipo = "soldado"

    def __init__(self,nombre, poder):
        self.nombre = nombre
        self.poder = poder

    def defender(self, proteger ):
        print(f"yo puedo ayudar {proteger}")

    def atacar(self, fusil ):
        print(f"puedo atacar con {fusil}")

        


"""soldado_1 = superheroe( "superman", "fuerza")
print(f"yo me llamo superman y tengo super fuerza")

villano = superheroe("ultraman", "volar")
print(f"Yo me llamo {villano} y puedo volar")"""
# Out:
# yo me llamo superman y tengo super fuerza
# Yo me llamo <__main__.superheroe object at 0x0000014DEB847A10> y puedo volar
