# %%
nombre = 'elias' #--> str
edad = 24 # int 
ciudad = 'san antonio' #--> str
print (nombre)
print(edad)
print(ciudad)
# Out:
# elias
# 24
# san antonio

# %%
print('hola mundo')
# Out:
# hola mundo

# %%
nombre = "elias"
apellido = "nunez"
print(nombre, apellido)
print(f"mi nombre es {nombre}{apellido}")
# Out:
# elias nunez
# mi nombre es eliasnunez

# %%
caramelos = int(input("cantidad_de_caramelos"))
ninos = int(input("cantidad_de_ninoz"))
print(cantidad_de_ninos //cantidad_de_caramelos)
# Out:
# 1

# %%
    
def desayuno():

    ingredientes1 = input("primer ingrediente")      
    ingredientes2 = input("segundo ingrediente")
    print(f"mi desayuno es {ingredientes1} {ingredientes2}")    

desayuno()      
desayuno()
# Out:
# mi desayuno es
# mi desayuno es

# %%
def comida_rapida(nombre_producto, tamano_del_pedido):
    print(f"tu pedido es {nombre_producto} {tamano_del_pedido}")

    comida_rapida("hamurguesa", )

# %%
def calcular_total(precio_del_producto):
