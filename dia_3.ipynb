# %%
def palabra_ingresada():
    palabra = "hola"
    print(palabra)
palabra_ingresada()

# %%
def verificar_letra(letra1, letra2):
    if letra1 == letra2:
        print("la letras son  iguales")

# %%
def verificar_palabra(palabra, numero):
    if len(palabra)== numero:
        return True
    else: 
        return False
    
resultado= verificar_palabra("python", 6)   
print(resultado)
# Out:
# True

# %%
ingresar_una_palabra = input("ingresar la palabrapalabra")

list("ingresar_una_palabrapalabra")
# Out:
# palabra ingresada

# %%
palabras_ingresadas = []

usuario = input('Ingrese la palabra')
palabras_ingresadas = list (usuario)
print (palabras_ingresadas)

usuario = input('Ingrese la palabra')
palabras_ingresadas = list (usuario)
print (palabras_ingresadas)

usuario = input('Ingrese la palabra')
palabras_ingresadas = list (usuario)
print (palabras_ingresadas)
# Out:
# ['p', 'e', 'r', 'r', 'o']
# ['g', 'a', 't', 'o']
# ['e', 'l', 'e', 'f', 'a', 'n', 't', 'e']

# %%
lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
def ve
