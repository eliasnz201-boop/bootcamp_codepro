# %%
contacto = {}

contacto ["Nombre"]= input("Cual es tu nombre")
print(contacto)

contacto["Edad"]= input("Ingrese su edad")
print(contacto)

contacto["Sexo"]= input("Ingrese su sexo ")
print(contacto)

contacto["Telefono"]= input("Ingrese su telefono")
print(contacto)

contacto["Correo"]= input("Ingrese su correo electronico")
print(contacto)
# Out:
# {'Nombre': 'Elias'}
# {'Nombre': 'Elias', 'Edad': '24'}
# {'Nombre': 'Elias', 'Edad': '24', 'Sexo': 'Mascu'}
# {'Nombre': 'Elias', 'Edad': '24', 'Sexo': 'Mascu', 'Telefono': '097523545'}
# {'Nombre': 'Elias', 'Edad': '24', 'Sexo': 'Mascu', 'Telefono': '097523545', 'Correo': 'elias74gmail'}

# %%
tarjeta_usuario ={}

opcion_usuario = input("Ingrese su opcion")

if opcion_usuario == "1":
    clave_usuario = input("ingrse su clave")
    valor_usuario = input("ingrese el valor")
    tarjeta_usuario[clave_usuario] = valor_usuario
    print(tarjeta_usuario)
elif opcion_usuario== "2"

# %%
agenda_de_contactos = {"Juan":{"numero";"0981123321"}, "Pedro":} 

opcion_usuario = input("Ingrese su opcio")
